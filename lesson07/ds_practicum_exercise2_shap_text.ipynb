# %% [markdown]
# # Text Classification
#
# We will use the [distilled version of the BERT base model](https://huggingface.co/distilbert-base-uncased) on a [dataset with news articles](https://huggingface.co/datasets/ag_news) from HuggingFace.
#
# The dataset consists of 120000 training and 7600 testing samples which can be divided into 4 classes: `World` (0), `Sports` (1), `Business` (2), and `Sci/Tech` (3)

# %%
# !pip install -qq transformers[torch] datasets shap
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 56.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 51.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 54.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 35.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 79.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 29.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 32.6 MB/s eta 0:00:00

# %%
DATASET = 'ag_news'
NUM_LABELS = 4
MODEL = 'distilbert-base-uncased'

# %% [markdown]
# Load the dataset with news articles:

# %%
from datasets import load_dataset

dataset = load_dataset(DATASET)
dataset
# Out:
# Downloading builder script:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.65k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.95k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/751k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7600 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 120000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 7600
#     })
# })

# %% [markdown]
# Load the tokenizer:

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(MODEL)
tokenizer
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# DistilBertTokenizerFast(name_or_path='distilbert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %% [markdown]
# Preprocess more samples from our dataset at once:

# %%
def preprocess_function(examples):
  # https://huggingface.co/docs/transformers/pad_truncation
  # truncation=True and padding='max_length' -> pads sequences with [PAD] token to given max sequence length
  return tokenizer(examples['text'], truncation=True, padding='max_length', return_tensors='pt')

# training on the whole dataset would take more than 5 hours :(
# train_dataset = dataset['train'].map(preprocess_function, batched=True)
# test_dataset = dataset['test'].map(preprocess_function, batched=True)

train_dataset = dataset['train'].shuffle(seed=42).select(range(2500)).map(preprocess_function, batched=True)
test_dataset = dataset['test'].shuffle(seed=42).select(range(500)).map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %% [markdown]
# Load the model:

# %%
from transformers import AutoModelForSequenceClassification

id2label = {0: 'World', 1: 'Sports', 2: 'Business', 3: 'Sci/Tech'}
label2id = {'World': 0, 'Sports': 1, 'Business': 2, 'Sci/Tech': 3}

model = AutoModelForSequenceClassification.from_pretrained(MODEL,
                                                           num_labels=NUM_LABELS,
                                                           id2label=id2label,
                                                           label2id=label2id)
model
# Out:
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.weight', 'classifier.bias', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# Define evaluation metrics and train our model:

# %%
from transformers import TrainingArguments, Trainer
from sklearn.metrics import accuracy_score
import numpy as np

def compute_metrics(p):
    logits = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
    preds = np.argmax(logits, axis=1)
    return {'accuracy': accuracy_score(p.label_ids, preds)}

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=2,
    per_device_train_batch_size=16,
    evaluation_strategy='epoch',
    learning_rate=5e-5,
    weight_decay=0.0
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='314' max='314' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [314/314 03:52, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.498501</td>
#       <td>0.856000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.379847</td>
#       <td>0.888000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=314, training_loss=0.36564682395594894, metrics={'train_runtime': 236.3229, 'train_samples_per_second': 21.157, 'train_steps_per_second': 1.329, 'total_flos': 662360616960000.0, 'train_loss': 0.36564682395594894, 'epoch': 2.0})

# %% [markdown]
# Use the trained model to get prediction for some random sentence of your choice using `pipeline`:
#
# https://huggingface.co/docs/transformers/main_classes/pipelines

# %%
from transformers import TextClassificationPipeline

pipe = TextClassificationPipeline(model=model, tokenizer=tokenizer, device=0)
pipe

# %%
pipe('This is my business news headline containing business money company words.')
# Out:
# [{'label': 'Business', 'score': 0.8748794198036194}]

# %%
# https://shap.readthedocs.io/en/latest/example_notebooks/api_examples/plots/text.html

import shap

def score_and_visualize(text):
    prediction = pipe([text])
    print(prediction[0])

    explainer = shap.Explainer(pipe)
    shap_values = explainer([text])
    shap.plots.text(shap_values)

res = score_and_visualize('This is my business news headline containing business money company words.')
# Out:
# {'label': 'Business', 'score': 0.8748794198036194}
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_usieyiccwpusnzjovqwp = '_tp_usieyiccwpusnzjovqwp_output_0';
#     document._zoom_usieyiccwpusnzjovqwp = undefined;
#     function _output_onclick_usieyiccwpusnzjovqwp(i) {
#         var next_id = undefined;
#
#         if (document._zoom_usieyiccwpusnzjovqwp !== undefined) {
#             document.getElementById(document._zoom_usieyiccwpusnzjovqwp+ '_zoom').style.display = 'none';
#
#             if (document._zoom_usieyiccwpusnzjovqwp === '_tp_usieyiccwpusnzjovqwp_output_' + i) {
#                 document.getElementById(document._zoom_usieyiccwpusnzjovqwp).style.display = 'block';
#                 document.getElementById(document._zoom_usieyiccwpusnzjovqwp+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_usieyiccwpusnzjovqwp).style.display = 'none';
#                 document.getElementById(document._zoom_usieyiccwpusnzjovqwp+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_usieyiccwpusnzjovqwp !== '_tp_usieyiccwpusnzjovqwp_output_' + i) {
#             next_id = '_tp_usieyiccwpusnzjovqwp_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_usieyiccwpusnzjovqwp = next_id;
#     }
#     function _output_onmouseover_usieyiccwpusnzjovqwp(i, el) {
#         if (document._zoom_usieyiccwpusnzjovqwp !== undefined) { return; }
#         if (document._hover_usieyiccwpusnzjovqwp !== undefined) {
#             document.getElementById(document._hover_usieyiccwpusnzjovqwp + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_usieyiccwpusnzjovqwp).style.display = 'none';
#         }
#         document.getElementById('_tp_usieyiccwpusnzjovqwp_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_usieyiccwpusnzjovqwp = '_tp_usieyiccwpusnzjovqwp_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_usieyiccwpusnzjovqwp_output_0_name"
#     onclick="_output_onclick_usieyiccwpusnzjovqwp(0)"
#     onmouseover="_output_onmouseover_usieyiccwpusnzjovqwp(0, this);">World</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_usieyiccwpusnzjovqwp_output_1_name"
#     onclick="_output_onclick_usieyiccwpusnzjovqwp(1)"
#     onmouseover="_output_onmouseover_usieyiccwpusnzjovqwp(1, this);">Sports</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_usieyiccwpusnzjovqwp_output_2_name"
#     onclick="_output_onclick_usieyiccwpusnzjovqwp(2)"
#     onmouseover="_output_onmouseover_usieyiccwpusnzjovqwp(2, this);">Business</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_usieyiccwpusnzjovqwp_output_3_name"
#     onclick="_output_onclick_usieyiccwpusnzjovqwp(3)"
#     onmouseover="_output_onmouseover_usieyiccwpusnzjovqwp(3, this);">Sci/Tech</div><br><br><div id='_tp_usieyiccwpusnzjovqwp_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.835228947159806%" y1="33" x2="47.835228947159806%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.835228947159806%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="36.27119295747567%" y1="33" x2="36.27119295747567%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.27119295747567%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="24.707156967791526%" y1="33" x2="24.707156967791526%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="24.707156967791526%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="13.143120978107385%" y1="33" x2="13.143120978107385%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="13.143120978107385%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.2</text><line x1="59.39926493684394%" y1="33" x2="59.39926493684394%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.39926493684394%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="70.96330092652809%" y1="33" x2="70.96330092652809%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="70.96330092652809%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="82.52733691621222%" y1="33" x2="82.52733691621222%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.52733691621222%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="24.707156967791526%" y1="33" x2="24.707156967791526%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="24.707156967791526%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="24.707156967791526%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="24.707156967791526%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="24.707156967791526%" y1="33" x2="24.707156967791526%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="24.707156967791526%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="24.707156967791526%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="24.707156967791526%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">World</tspan>(inputs)</text><rect x="24.707156967791526%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="24.707156967791526%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="24.707156967791526%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="24.707156967791526%" width="-0.0%" y="40" height="18" style="fill:rgb(0.0, 138.56128015770727, 250.76166088685738); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform=" ...

# %%
score_and_visualize('Some player of hockey did something on ice. Goal was made.')
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# {'label': 'Sports', 'score': 0.9733905792236328}
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_zpotbpnweyceprgdxgpq = '_tp_zpotbpnweyceprgdxgpq_output_0';
#     document._zoom_zpotbpnweyceprgdxgpq = undefined;
#     function _output_onclick_zpotbpnweyceprgdxgpq(i) {
#         var next_id = undefined;
#
#         if (document._zoom_zpotbpnweyceprgdxgpq !== undefined) {
#             document.getElementById(document._zoom_zpotbpnweyceprgdxgpq+ '_zoom').style.display = 'none';
#
#             if (document._zoom_zpotbpnweyceprgdxgpq === '_tp_zpotbpnweyceprgdxgpq_output_' + i) {
#                 document.getElementById(document._zoom_zpotbpnweyceprgdxgpq).style.display = 'block';
#                 document.getElementById(document._zoom_zpotbpnweyceprgdxgpq+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_zpotbpnweyceprgdxgpq).style.display = 'none';
#                 document.getElementById(document._zoom_zpotbpnweyceprgdxgpq+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_zpotbpnweyceprgdxgpq !== '_tp_zpotbpnweyceprgdxgpq_output_' + i) {
#             next_id = '_tp_zpotbpnweyceprgdxgpq_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_zpotbpnweyceprgdxgpq = next_id;
#     }
#     function _output_onmouseover_zpotbpnweyceprgdxgpq(i, el) {
#         if (document._zoom_zpotbpnweyceprgdxgpq !== undefined) { return; }
#         if (document._hover_zpotbpnweyceprgdxgpq !== undefined) {
#             document.getElementById(document._hover_zpotbpnweyceprgdxgpq + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_zpotbpnweyceprgdxgpq).style.display = 'none';
#         }
#         document.getElementById('_tp_zpotbpnweyceprgdxgpq_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_zpotbpnweyceprgdxgpq = '_tp_zpotbpnweyceprgdxgpq_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_zpotbpnweyceprgdxgpq_output_0_name"
#     onclick="_output_onclick_zpotbpnweyceprgdxgpq(0)"
#     onmouseover="_output_onmouseover_zpotbpnweyceprgdxgpq(0, this);">World</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_zpotbpnweyceprgdxgpq_output_1_name"
#     onclick="_output_onclick_zpotbpnweyceprgdxgpq(1)"
#     onmouseover="_output_onmouseover_zpotbpnweyceprgdxgpq(1, this);">Sports</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_zpotbpnweyceprgdxgpq_output_2_name"
#     onclick="_output_onclick_zpotbpnweyceprgdxgpq(2)"
#     onmouseover="_output_onmouseover_zpotbpnweyceprgdxgpq(2, this);">Business</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_zpotbpnweyceprgdxgpq_output_3_name"
#     onclick="_output_onclick_zpotbpnweyceprgdxgpq(3)"
#     onmouseover="_output_onmouseover_zpotbpnweyceprgdxgpq(3, this);">Sci/Tech</div><br><br><div id='_tp_zpotbpnweyceprgdxgpq_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.966200940044615%" y1="33" x2="50.966200940044615%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.966200940044615%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.44200199156238%" y1="33" x2="36.44200199156238%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.44200199156238%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="21.917803043080134%" y1="33" x2="21.917803043080134%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.917803043080134%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="7.393604094597887%" y1="33" x2="7.393604094597887%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="7.393604094597887%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="65.49039988852685%" y1="33" x2="65.49039988852685%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.49039988852685%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="80.0145988370091%" y1="33" x2="80.0145988370091%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="80.0145988370091%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="14.655703568839012%" y1="33" x2="14.655703568839012%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.655703568839012%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="14.655703568839012%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="14.655703568839012%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="14.655703568839012%" y1="33" x2="14.655703568839012%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.655703568839012%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="14.655703568839012%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="14.655703568839012%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">World</tspan>(inputs)</text><rect x="14.655703568839012%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="14.655703568839012%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="14.655703568839012%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="14.655703568839012%" width="-0.0%" y="40" height="18" style="fill:rgb(0.0, 138.56128015770727, 250.76166088685738); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(0,0)" x="14.655703568839012%" y="40" width="8" height="18" style="fill:rgb(0.0, 138.56128015770727, 250.76166088685738)"/><g transform="translate(-6.0,0)">  <svg x="14.655703568839012%" y="40" height="18" overflow="visible" width="30">    <path d ...

# %%
# what happens when we try to predict the label of a sentence that actually
# belongs to a class that wasn't in our data?
score_and_visualize('This sentence is about fashion: It is winter so we have to wear sweaters, vests, and trousers.')
# Out:
# {'label': 'Sci/Tech', 'score': 0.8998322486877441}
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_kqfsmgratucleynbgwlu = '_tp_kqfsmgratucleynbgwlu_output_0';
#     document._zoom_kqfsmgratucleynbgwlu = undefined;
#     function _output_onclick_kqfsmgratucleynbgwlu(i) {
#         var next_id = undefined;
#
#         if (document._zoom_kqfsmgratucleynbgwlu !== undefined) {
#             document.getElementById(document._zoom_kqfsmgratucleynbgwlu+ '_zoom').style.display = 'none';
#
#             if (document._zoom_kqfsmgratucleynbgwlu === '_tp_kqfsmgratucleynbgwlu_output_' + i) {
#                 document.getElementById(document._zoom_kqfsmgratucleynbgwlu).style.display = 'block';
#                 document.getElementById(document._zoom_kqfsmgratucleynbgwlu+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_kqfsmgratucleynbgwlu).style.display = 'none';
#                 document.getElementById(document._zoom_kqfsmgratucleynbgwlu+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_kqfsmgratucleynbgwlu !== '_tp_kqfsmgratucleynbgwlu_output_' + i) {
#             next_id = '_tp_kqfsmgratucleynbgwlu_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_kqfsmgratucleynbgwlu = next_id;
#     }
#     function _output_onmouseover_kqfsmgratucleynbgwlu(i, el) {
#         if (document._zoom_kqfsmgratucleynbgwlu !== undefined) { return; }
#         if (document._hover_kqfsmgratucleynbgwlu !== undefined) {
#             document.getElementById(document._hover_kqfsmgratucleynbgwlu + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_kqfsmgratucleynbgwlu).style.display = 'none';
#         }
#         document.getElementById('_tp_kqfsmgratucleynbgwlu_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_kqfsmgratucleynbgwlu = '_tp_kqfsmgratucleynbgwlu_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_kqfsmgratucleynbgwlu_output_0_name"
#     onclick="_output_onclick_kqfsmgratucleynbgwlu(0)"
#     onmouseover="_output_onmouseover_kqfsmgratucleynbgwlu(0, this);">World</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_kqfsmgratucleynbgwlu_output_1_name"
#     onclick="_output_onclick_kqfsmgratucleynbgwlu(1)"
#     onmouseover="_output_onmouseover_kqfsmgratucleynbgwlu(1, this);">Sports</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_kqfsmgratucleynbgwlu_output_2_name"
#     onclick="_output_onclick_kqfsmgratucleynbgwlu(2)"
#     onmouseover="_output_onmouseover_kqfsmgratucleynbgwlu(2, this);">Business</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_kqfsmgratucleynbgwlu_output_3_name"
#     onclick="_output_onclick_kqfsmgratucleynbgwlu(3)"
#     onmouseover="_output_onmouseover_kqfsmgratucleynbgwlu(3, this);">Sci/Tech</div><br><br><div id='_tp_kqfsmgratucleynbgwlu_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.717844571388994%" y1="33" x2="50.717844571388994%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.717844571388994%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="40.574275657111194%" y1="33" x2="40.574275657111194%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="40.574275657111194%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="30.430706742833397%" y1="33" x2="30.430706742833397%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.430706742833397%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="20.287137828555593%" y1="33" x2="20.287137828555593%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.287137828555593%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="10.143568914277797%" y1="33" x2="10.143568914277797%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.143568914277797%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="60.861413485666795%" y1="33" x2="60.861413485666795%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.861413485666795%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="71.0049823999446%" y1="33" x2="71.0049823999446%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="71.0049823999446%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="81.14855131422239%" y1="33" x2="81.14855131422239%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.14855131422239%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="91.2921202285002%" y1="33" x2="91.2921202285002%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.2921202285002%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="0.0%" y1="33" x2="0.0%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="0.0%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="0.0%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="0.0%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="0.0%" y1="33" x2="0.0%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="0.0%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="0.0%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="0.0%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">World</tspan>(inputs)</text><rect x="0.0%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="0.0%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="0.0%" y="40" height="18" overflow="visible ...
